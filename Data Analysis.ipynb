# %%
df.rename(columns={"ActivityDate": 'Date'})
# Out:
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  3/25/2016       11004                 33
# 1    1503960366  3/26/2016       17609                 89
# 2    1503960366  3/27/2016       12736                 56
# 3    1503960366  3/28/2016       13231                 39
# 4    1503960366  3/29/2016       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391   4/8/2016       23014                 70
# 453  8877689391   4/9/2016       16470                 90
# 454  8877689391  4/10/2016       28497                128
# 455  8877689391  4/11/2016       10622                 18
# 456  8877689391  4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 8 columns]

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours
# 0            1054        18.0
# 1             968        16.0
# 2             934        16.0
# 3            1363        23.0
# 4            1062        18.0
# ..            ...         ...
# 452          1440        24.0
# 453          1440        24.0
# 454          1440        24.0
# 455          1440        24.0
# 456           589        10.0
#
# [457 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   ActivityDate          457 non-null    object
#  2   TotalSteps            457 non-null    int64
#  3   VeryActiveMinutes     457 non-null    int64
#  4   FairlyActiveMinutes   457 non-null    int64
#  5   LightlyActiveMinutes  457 non-null    int64
#  6   SedentaryMinutes      457 non-null    int64
#  7   Calories              457 non-null    int64
#  8   TotalMinutes          457 non-null    int64
#  9   TotalHours            457 non-null    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 35.8+ KB

# %%
import datetime as dt 
df['DayOfWeek'] = df.Date.dt.day_name()
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16244\279727774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] = df.Date.dt.day_name()
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours DayOfWeek
# 0            1054        18.0    Friday
# 1             968        16.0  Saturday
# 2             934        16.0    Sunday
# 3            1363        23.0    Monday
# 4            1062        18.0   Tuesday
# ..            ...         ...       ...
# 452          1440        24.0    Friday
# 453          1440        24.0  Saturday
# 454          1440        24.0    Sunday
# 455          1440        24.0    Monday
# 456           589        10.0   Tuesday
#
# [457 rows x 11 columns]

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
cols = ['Id','ActivityDate','TotalSteps','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories']
df   = df[cols]
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 8 columns]

# %%
 df.rename(columns={"ActivityDate": 'Date'}, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.rename(columns={"ActivityDate": 'Date'}, inplace=True)
#       2 df
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
#                  Id    TotalSteps  VeryActiveMinutes  FairlyActiveMinutes  \
# count  4.570000e+02    457.000000         457.000000           457.000000
# mean   4.628595e+09   6546.562363          16.623632            13.070022
# std    2.293781e+09   5398.493064          28.919704            36.208635
# min    1.503960e+09      0.000000           0.000000             0.000000
# 25%    2.347168e+09   1988.000000           0.000000             0.000000
# 50%    4.057193e+09   5986.000000           0.000000             1.000000
# 75%    6.391747e+09  10198.000000          25.000000            16.000000
# max    8.877689e+09  28497.000000         202.000000           660.000000
#
#        LightlyActiveMinutes  SedentaryMinutes     Calories
# count            457.000000        457.000000   457.000000
# mean             170.070022        995.282276  2189.452954
# std              122.205372        337.021404   815.484523
# min                0.000000         32.000000     0.000000
# 25%               64.000000        728.000000  1776.000000
# 50%              181.000000       1057.000000  2062.000000
# 75%              257.000000       1285.000000  2667.000000
# max              720.000000       1440.000000  4562.000000

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 8 columns]

# %%
df['TotalMinutes'] = df.VeryActiveMinutes+ df.FairlyActiveMinutes+df.LightlyActiveMinutes+df.SedentaryMinutes
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9880\2794897696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalMinutes'] = df.VeryActiveMinutes+ df.FairlyActiveMinutes+df.LightlyActiveMinutes+df.SedentaryMinutes

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes
# 0            1054
# 1             968
# 2             934
# 3            1363
# 4            1062
# ..            ...
# 452          1440
# 453          1440
# 454          1440
# 455          1440
# 456           589
#
# [457 rows x 9 columns]

# %%
df['TotalHours'] = round(df.TotalMinutes/60)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2336\1430137410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalHours'] = round(df.TotalMinutes/60)
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  3/25/2016       11004                 33
# 1    1503960366  3/26/2016       17609                 89
# 2    1503960366  3/27/2016       12736                 56
# 3    1503960366  3/28/2016       13231                 39
# 4    1503960366  3/29/2016       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391   4/8/2016       23014                 70
# 453  8877689391   4/9/2016       16470                 90
# 454  8877689391  4/10/2016       28497                128
# 455  8877689391  4/11/2016       10622                 18
# 456  8877689391  4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours
# 0            1054        18.0
# 1             968        16.0
# 2             934        16.0
# 3            1363        23.0
# 4            1062        18.0
# ..            ...         ...
# 452          1440        24.0
# 453          1440        24.0
# 454          1440        24.0
# 455          1440        24.0
# 456           589        10.0
#
# [457 rows x 10 columns]

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes
# 0            1054
# 1             968
# 2             934
# 3            1363
# 4            1062
# ..            ...
# 452          1440
# 453          1440
# 454          1440
# 455          1440
# 456           589
#
# [457 rows x 9 columns]

# %%
df.Date= pd.to_datetime(df.Date)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9880\1506598469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Date= pd.to_datetime(df.Date)
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes
# 0            1054
# 1             968
# 2             934
# 3            1363
# 4            1062
# ..            ...
# 452          1440
# 453          1440
# 454          1440
# 455          1440
# 456           589
#
# [457 rows x 9 columns]

# %%
df['TotalHours']= round(df.TotalMinutes/60)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9880\2791489571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalHours']= round(df.TotalMinutes/60)
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours
# 0            1054        18.0
# 1             968        16.0
# 2             934        16.0
# 3            1363        23.0
# 4            1062        18.0
# ..            ...         ...
# 452          1440        24.0
# 453          1440        24.0
# 454          1440        24.0
# 455          1440        24.0
# 456           589        10.0
#
# [457 rows x 10 columns]

# %%
import datetime as dt
df['DayOfWeek'] = df.Date.dt.day_name()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9880\30055317.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] = df.Date.dt.day_name()

# %%
df
# Out:
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours DayOfWeek
# 0            1054        18.0    Friday
# 1             968        16.0  Saturday
# 2             934        16.0    Sunday
# 3            1363        23.0    Monday
# 4            1062        18.0   Tuesday
# ..            ...         ...       ...
# 452          1440        24.0    Friday
# 453          1440        24.0  Saturday
# 454          1440        24.0    Sunday
# 455          1440        24.0    Monday
# 456           589        10.0   Tuesday
#
# [457 rows x 11 columns]

# %%
df.describe()
# Out:
#                  Id                           Date    TotalSteps  \
# count  4.570000e+02                            457    457.000000
# mean   4.628595e+09  2016-04-04 04:40:26.258205696   6546.562363
# min    1.503960e+09            2016-03-12 00:00:00      0.000000
# 25%    2.347168e+09            2016-04-02 00:00:00   1988.000000
# 50%    4.057193e+09            2016-04-05 00:00:00   5986.000000
# 75%    6.391747e+09            2016-04-08 00:00:00  10198.000000
# max    8.877689e+09            2016-04-12 00:00:00  28497.000000
# std    2.293781e+09                            NaN   5398.493064
#
#        VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# count         457.000000           457.000000            457.000000
# mean           16.623632            13.070022            170.070022
# min             0.000000             0.000000              0.000000
# 25%             0.000000             0.000000             64.000000
# 50%             0.000000             1.000000            181.000000
# 75%            25.000000            16.000000            257.000000
# max           202.000000           660.000000            720.000000
# std            28.919704            36.208635            122.205372
#
#        SedentaryMinutes     Calories  TotalMinutes  TotalHours
# count        457.000000   457.000000    457.000000  457.000000
# mean         995.282276  2189.452954   1195.045952   19.919037
# min           32.000000     0.000000     41.000000    1.000000
# 25%          728.000000  1776.000000    985.000000   16.000000
# 50%         1057.000000  2062.000000   1440.000000   24.000000
# 75%         1285.000000  2667.000000   1440.000000   24.000000
# max         1440.000000  4562.000000   1440.000000   24.000000
# std          337.021404   815.484523    306.457382    5.123904

# %%
print(dir(plt.hist))
# Out:
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__getstate__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__signature__', '__sizeof__', '__str__', '__subclasshook__', '__type_params__', '__wrapped__']

# %%
plt.figure(figsize=((6,6)))
plt.hist(df.DayOfWeek,bins=7,color='green' , width=0.5)
plt.grid(True)
plt.xlabel('Day of week ')
plt.ylabel('Freq')
plt.title('Freq By Day of week')
# Out:
# Text(0.5, 1.0, 'Freq By Day of week')

# %%
df
# Out:
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours DayOfWeek
# 0            1054        18.0    Friday
# 1             968        16.0  Saturday
# 2             934        16.0    Sunday
# 3            1363        23.0    Monday
# 4            1062        18.0   Tuesday
# ..            ...         ...       ...
# 452          1440        24.0    Friday
# 453          1440        24.0  Saturday
# 454          1440        24.0    Sunday
# 455          1440        24.0    Monday
# 456           589        10.0   Tuesday
#
# [457 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder 
import warnings
warnings.filterwarnings('ignore')

# %%
le= LabelEncoder()

# %%
df['DayOfWeek'] = le.fit_transform(df['DayOfWeek'])

# %%
df['DayOfWeek'].value_counts()
# Out:
# DayOfWeek
# 2    75
# 0    73
# 5    73
# 3    72
# 1    68
# 6    48
# 4    48
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                             Id      Date  TotalSteps  VeryActiveMinutes  \
# Id                    1.000000  0.130204    0.138662           0.315967
# Date                  0.130204  1.000000    0.078901           0.089403
# TotalSteps            0.138662  0.078901    1.000000           0.699699
# VeryActiveMinutes     0.315967  0.089403    0.699699           1.000000
# FairlyActiveMinutes   0.001878  0.020474    0.238389           0.167764
# LightlyActiveMinutes -0.073104  0.140394    0.654418           0.199697
# SedentaryMinutes     -0.027336 -0.295011   -0.285258          -0.177652
# Calories              0.290868 -0.196360    0.581380           0.518905
# TotalMinutes         -0.029175 -0.257593    0.041449          -0.001548
# TotalHours           -0.030675 -0.257516    0.042639           0.000756
# DayOfWeek            -0.019584  0.012460   -0.050762          -0.029882
#
#                       FairlyActiveMinutes  LightlyActiveMinutes  \
# Id                               0.001878             -0.073104
# Date                             0.020474              0.140394
# TotalSteps                       0.238389              0.654418
# VeryActiveMinutes                0.167764              0.199697
# FairlyActiveMinutes              1.000000              0.095449
# LightlyActiveMinutes             0.095449              1.000000
# SedentaryMinutes                -0.142598             -0.393499
# Calories                         0.334550              0.377249
# TotalMinutes                     0.015226             -0.003854
# TotalHours                       0.014841             -0.002054
# DayOfWeek                       -0.060021             -0.053570
#
#                       SedentaryMinutes  Calories  TotalMinutes  TotalHours  \
# Id                           -0.027336  0.290868     -0.029175   -0.030675
# Date                         -0.295011 -0.196360     -0.257593   -0.257516
# TotalSteps                   -0.285258  0.581380      0.041449    0.042639
# VeryActiveMinutes            -0.177652  0.518905     -0.001548    0.000756
# FairlyActiveMinutes          -0.142598  0.334550      0.015226    0.014841
# LightlyActiveMinutes         -0.393499  0.377249     -0.003854   -0.002054
# SedentaryMinutes              1.000000  0.011824      0.909206    0.907674
# Calories                      0.011824  1.000000      0.251934    0.254466
# TotalMinutes                  0.909206  0.251934      1.000000    0.999205
# TotalHours                    0.907674  0.254466      0.999205    1.000000
# DayOfWeek                    -0.108579 -0.103287     -0.150682   -0.150741
#
#                       DayOfWeek
# Id                    -0.019584
# Date                   0.012460
# TotalSteps            -0.050762
# VeryActiveMinutes     -0.029882
# FairlyActiveMinutes   -0.060021
# LightlyActiveMinutes  -0.053570
# SedentaryMinutes      -0.108579
# Calories              -0.103287
# TotalMinutes          -0.150682
# TotalHours            -0.150741
# DayOfWeek              1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=((8,6)))
plt.scatter(df.TotalSteps, df.Calories,c= df.Calories )
median_steps = 5986
median_calories = 2062
plt.axhline(median_calories, color= 'brown', label= 'Median of calories' )
plt.axvline(median_steps,     color= 'blue', label= 'Median of steps' )

plt.xlabel('Steps')
plt.ylabel('Calories')

plt.title('Calories by total steps')

plt.show()

# %%
df.describe()
# Out:
#                  Id                           Date    TotalSteps  \
# count  4.570000e+02                            457    457.000000
# mean   4.628595e+09  2016-04-04 04:40:26.258205696   6546.562363
# min    1.503960e+09            2016-03-12 00:00:00      0.000000
# 25%    2.347168e+09            2016-04-02 00:00:00   1988.000000
# 50%    4.057193e+09            2016-04-05 00:00:00   5986.000000
# 75%    6.391747e+09            2016-04-08 00:00:00  10198.000000
# max    8.877689e+09            2016-04-12 00:00:00  28497.000000
# std    2.293781e+09                            NaN   5398.493064
#
#        VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# count         457.000000           457.000000            457.000000
# mean           16.623632            13.070022            170.070022
# min             0.000000             0.000000              0.000000
# 25%             0.000000             0.000000             64.000000
# 50%             0.000000             1.000000            181.000000
# 75%            25.000000            16.000000            257.000000
# max           202.000000           660.000000            720.000000
# std            28.919704            36.208635            122.205372
#
#        SedentaryMinutes     Calories  TotalMinutes  TotalHours   DayOfWeek
# count        457.000000   457.000000    457.000000  457.000000  457.000000
# mean         995.282276  2189.452954   1195.045952   19.919037    2.798687
# min           32.000000     0.000000     41.000000    1.000000    0.000000
# 25%          728.000000  1776.000000    985.000000   16.000000    1.000000
# 50%         1057.000000  2062.000000   1440.000000   24.000000    3.000000
# 75%         1285.000000  2667.000000   1440.000000   24.000000    5.000000
# max         1440.000000  4562.000000   1440.000000   24.000000    6.000000
# std          337.021404   815.484523    306.457382    5.123904    1.963192

# %%
VeryActiveMinutes= df.VeryActiveMinutes.sum()
FairlyActiveMinutes=df.FairlyActiveMinutes.sum()
LightlyActiveMinutes=df.LightlyActiveMinutes.sum()
SedentaryMinutes=df.SedentaryMinutes.sum()
Minutes= [VeryActiveMinutes,FairlyActiveMinutes,LightlyActiveMinutes,SedentaryMinutes]
labels=["VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes"]
plt.pie(Minutes,labels=labels,autopct='%1.1f%%')
plt.show()
